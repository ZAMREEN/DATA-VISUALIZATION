# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("consumer_electronics_sales_data.csv")
df
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 1          5875   Smart Watches       Samsung    980.389404           35
# 2          5876         Tablets       Samsung   2606.718293           63
# 3          5877     Smartphones       Samsung    870.395450           63
# 4          5878         Tablets          Sony   1798.955875           57
# ...         ...             ...           ...           ...          ...
# 8995      14869   Smart Watches       Samsung   1041.149163           36
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8997      14871      Headphones       Samsung   2887.369597           28
# 8998      14872         Tablets            HP   1490.453964           38
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %%
data=df.head(50)

# %%
df["ProductBrand"].unique()
# Out:
# array(['Other Brands', 'Samsung', 'Sony', 'HP', 'Apple'], dtype=object)

# %%
df["ProductCategory"].unique()
# Out:
# array(['Smartphones', 'Smart Watches', 'Tablets', 'Laptops', 'Headphones'],
#       dtype=object)

# %%
df["CustomerAge"].unique()
# Out:
# array([18, 35, 63, 57, 37, 26, 19, 66, 20, 38, 48, 62, 54, 33, 29, 28, 43,
#        58, 34, 65, 67, 23, 61, 64, 55, 56, 42, 39, 50, 52, 40, 41, 30, 47,
#        60, 21, 49, 27, 51, 25, 69, 44, 24, 22, 53, 68, 46, 45, 31, 32, 36,
#        59], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             50 non-null     int64
#  1   ProductCategory       50 non-null     object
#  2   ProductBrand          50 non-null     object
#  3   ProductPrice          50 non-null     float64
#  4   CustomerAge           50 non-null     int64
#  5   CustomerGender        50 non-null     int64
#  6   PurchaseFrequency     50 non-null     int64
#  7   CustomerSatisfaction  50 non-null     int64
#  8   PurchaseIntent        50 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 3.6+ KB

# %%
x=data.describe()
x
# Out:
#         ProductID  ProductPrice  CustomerAge  CustomerGender  \
# count    50.00000     50.000000    50.000000       50.000000
# mean   5898.50000   1525.054283    43.620000        0.540000
# std      14.57738    787.318141    14.804701        0.503457
# min    5874.00000    206.667815    18.000000        0.000000
# 25%    5886.25000    881.159787    30.750000        0.000000
# 50%    5898.50000   1538.680919    41.500000        1.000000
# 75%    5910.75000   2265.579050    57.000000        1.000000
# max    5923.00000   2815.031731    67.000000        1.000000
#
#        PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# count          50.000000             50.000000       50.000000
# mean            9.140000              3.180000        0.640000
# std             6.111248              1.424136        0.484873
# min             1.000000              1.000000        0.000000
# 25%             3.250000              2.000000        0.000000
# ...

# %%
sns.histplot(x="CustomerAge",kde=True,stat="count",data=df)
plt.title("Distribution of customer ages")
plt.show()

# %%
sns.kdeplot(x="ProductPrice", data=data)
plt.title("Distribution of ProductPrice")
plt.show()

# %%
sns.barplot(x="ProductBrand",y="ProductPrice",color="#DE3163",palette="Spectral",data=data)
plt.title("Total product prizes of diffrent brand")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\613398504.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="ProductBrand",y="ProductPrice",color="#DE3163",palette="Spectral",data=data)

# %%
sns.boxplot(x="ProductCategory",y="ProductPrice",color="#DE3163",palette="Blues", width=1,data=data)
plt.title("Price Range of Products by Category")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\1954918524.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="ProductCategory",y="ProductPrice",color="#DE3163",palette="Blues", width=1,data=data)

# %%
sns.countplot(x="ProductBrand",hue="CustomerGender",data=data)
plt.title("Count Of ProductBrand Purchased By Male & Female")
plt.show()

# %%
sns.countplot(x="ProductBrand",hue="PurchaseIntent",data=data)
plt.title("Purchase Intent for Different Brand")
plt.show()

# %%
sns.lineplot(x="CustomerSatisfaction",y="CustomerAge",marker="o",ci=None,data=data)
plt.title("Trends in CustomerSatisfaction Over Age")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\1514947228.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="CustomerSatisfaction",y="CustomerAge",marker="o",ci=None,data=data)

# %%
sns.pairplot(data=data, height=2)
plt.show()

# %%
df['ProductBrand'].unique()
# Out:
# array(['Other Brands', 'Samsung', 'Sony', 'HP', 'Apple'], dtype=object)

# %%
df1=df.groupby(['ProductBrand'])['CustomerSatisfaction'].count()
df1
# Out:
# ProductBrand
# Apple           1760
# HP              1820
# Other Brands    1776
# Samsung         1854
# Sony            1790
# Name: CustomerSatisfaction, dtype: int64

# %%
labels = ['Other Brands', 'Samsung', 'Sony', 'HP', 'Apple'] 
expld=[0,0,0,0,0.2]
plt.pie(df1, labels=labels,explode=expld,shadow=True,autopct='%1.1f%%')
plt.legend(title="Brand")
plt.title("customer satisfaction")
plt.show()

# %%
res=df.groupby(["ProductBrand"]).count()
res
# Out:
#               ProductID  ProductCategory  ProductPrice  CustomerAge  \
# ProductBrand
# Apple              1760             1760          1760         1760
# HP                 1820             1820          1820         1820
# Other Brands       1776             1776          1776         1776
# Samsung            1854             1854          1854         1854
# Sony               1790             1790          1790         1790
#
#               CustomerGender  PurchaseFrequency  CustomerSatisfaction  \
# ProductBrand
# Apple                   1760               1760                  1760
# HP                      1820               1820                  1820
# Other Brands            1776               1776                  1776
# Samsung                 1854               1854                  1854
# Sony                    1790               1790                  1790
#
#               PurchaseIntent
# ProductBrand
# Apple                   1760
# HP                      1820
# ...

# %%
res=df.groupby(["ProductBrand"])["ProductCategory"].count().reset_index()
res
# Out:
#    ProductBrand  ProductCategory
# 0         Apple             1760
# 1            HP             1820
# 2  Other Brands             1776
# 3       Samsung             1854
# 4          Sony             1790

# %%
res1=df.groupby(["ProductBrand"])["PurchaseFrequency"].count()
res1
# Out:
# ProductBrand
# Apple           1760
# HP              1820
# Other Brands    1776
# Samsung         1854
# Sony            1790
# Name: PurchaseFrequency, dtype: int64

# %%
labels = ['Apple','HP','Other Brands','Samsung','Sony'] 
expld=[0,0,0.2,0,0]
plt.pie(res1, labels=labels,explode=expld,shadow=True,autopct='%1.1f%%')
plt.legend(title="Brand")
plt.title("Purchase Frequency for product brand")
plt.show()

# %%
df2=df.groupby(['ProductBrand'])['PurchaseIntent'].count().reset_index()
df2
# Out:
#    ProductBrand  PurchaseIntent
# 0         Apple            1760
# 1            HP            1820
# 2  Other Brands            1776
# 3       Samsung            1854
# 4          Sony            1790

# %%
sns.barplot(data=df2, x="ProductBrand", y="PurchaseIntent",width=0.5,palette="rocket")
plt.title("PurchaseIntent by Product Brand")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\1453107160.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df2, x="ProductBrand", y="PurchaseIntent",width=0.5,palette="rocket")

# %%
df_smartphones = df[df['ProductCategory'] == 'Smartphones']
df_smartphones
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 3          5877     Smartphones       Samsung    870.395450           63
# 5          5879     Smartphones       Samsung    373.148325           37
# 6          5880     Smartphones       Samsung   2330.036775           26
# 7          5881     Smartphones            HP    780.101494           35
# ...         ...             ...           ...           ...          ...
# 8981      14855     Smartphones            HP    469.957795           22
# 8987      14861     Smartphones       Samsung   1568.510460           50
# 8993      14867     Smartphones         Apple    103.761976           47
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %%
df2 = df_smartphones.groupby('ProductBrand')['ProductPrice'].sum().reset_index()
df2
# Out:
#    ProductBrand   ProductPrice
# 0         Apple  504406.482394
# 1            HP  552640.539623
# 2  Other Brands  530441.828356
# 3       Samsung  587161.196512
# 4          Sony  548742.535801

# %%
sns.lmplot(data=data, x="ProductPrice", y="CustomerAge",ci=None)
plt.show()

# %%
sns.barplot(data=data,x="ProductCategory",y="PurchaseFrequency",width=0.5,palette="crest")
plt.title("Sales Count by ProductCategory")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\920909689.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="ProductCategory",y="PurchaseFrequency",width=0.5,palette="crest")

# %%
 sns.barplot(data=data,x="ProductBrand",y="PurchaseFrequency",width=0.5,palette="mako")
plt.title("Sales Count by ProductBrand")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\2908146171.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="ProductBrand",y="PurchaseFrequency",width=0.5,palette="mako")

# %%
sns.histplot(data=data,x="CustomerAge",kde=True,)
plt.title("Distribution of Customer Ages")
plt.show()

# %%
sns.histplot(data=data,x="ProductPrice")
plt.title("Distribution of Product Prices")
plt.show()

# %%
sns.boxplot(x="CustomerAge",y="ProductCategory",color="#DE3163",palette="Blues", width=1,data=data)
plt.title("Customer Age Range by Product Category")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\78716294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="CustomerAge",y="ProductCategory",color="#DE3163",palette="Blues", width=1,data=data)

# %%
sns.lineplot(x="PurchaseFrequency",y="CustomerAge",marker="o",ci=None,data=data)
plt.title("Trends in Purchase Frequency Over age")
plt.show()
# Out:
# C:\Users\banuz\AppData\Local\Temp\ipykernel_33820\1405394380.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="PurchaseFrequency",y="CustomerAge",marker="o",ci=None,data=data)

# %%
le=LabelEncoder()
df["ProductCategory"]=le.fit_transform(df["ProductCategory"])
df["ProductBrand"]=le.fit_transform(df["ProductBrand"])

df
# Out:
#       ProductID  ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874                3             2    312.949668           18
# 1          5875                2             3    980.389404           35
# 2          5876                4             3   2606.718293           63
# 3          5877                3             3    870.395450           63
# 4          5878                4             4   1798.955875           57
# ...         ...              ...           ...           ...          ...
# 8995      14869                2             3   1041.149163           36
# 8996      14870                3             3   1485.694311           57
# 8997      14871                0             3   2887.369597           28
# 8998      14872                4             1   1490.453964           38
# 8999      14873                3             4   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %%
corr=df.corr()
corr
# Out:
#                       ProductID  ProductCategory  ProductBrand  ProductPrice  \
# ProductID              1.000000        -0.000541      0.010111      0.022327
# ProductCategory       -0.000541         1.000000      0.002044     -0.019288
# ProductBrand           0.010111         0.002044      1.000000      0.012437
# ProductPrice           0.022327        -0.019288      0.012437      1.000000
# CustomerAge           -0.005579         0.012900     -0.004649     -0.009322
# CustomerGender         0.017049         0.006489     -0.029625      0.001835
# PurchaseFrequency      0.012688        -0.024154      0.017497      0.009281
# CustomerSatisfaction  -0.001504        -0.002354     -0.020234      0.002112
# PurchaseIntent        -0.006596         0.010940     -0.022632     -0.017512
#
#                       CustomerAge  CustomerGender  PurchaseFrequency  \
# ProductID               -0.005579        0.017049           0.012688
# ...

# %%
sns.heatmap(corr,cmap="Blues",annot=corr.rank(axis="columns"))
# Out:
# <Axes: >

# %%
crr=x.corr()
crr
# Out:
#                       ProductID  ProductPrice  CustomerAge  CustomerGender  \
# ProductID              1.000000      0.541000     0.274121       -0.650396
# ProductPrice           0.541000      1.000000     0.704531       -0.488607
# CustomerAge            0.274121      0.704531     1.000000        0.231140
# CustomerGender        -0.650396     -0.488607     0.231140        1.000000
# PurchaseFrequency     -0.548113     -0.153301     0.532570        0.935442
# CustomerSatisfaction  -0.621686     -0.431083     0.295620        0.997674
# PurchaseIntent        -0.649860     -0.488421     0.231554        0.999998
#
#                       PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ProductID                     -0.548113             -0.621686       -0.649860
# ProductPrice                  -0.153301             -0.431083       -0.488421
# CustomerAge                    0.532570              0.295620        0.231554
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
x=df[["CustomerAge","CustomerGender","PurchaseFrequency","CustomerSatisfaction"]]
y=df["PurchaseIntent" ]

# %%
x
# Out:
#       CustomerAge  CustomerGender  PurchaseFrequency  CustomerSatisfaction
# 0              18               0                  2                     1
# 1              35               1                  7                     2
# 2              63               0                  1                     5
# 3              63               1                 10                     3
# 4              57               0                 17                     3
# ...           ...             ...                ...                   ...
# 8995           36               1                 16                     4
# 8996           57               0                  5                     1
# 8997           28               0                 18                     4
# 8998           38               0                  4                     2
# 8999           62               0                 15                     2
#
# [9000 rows x 4 columns]

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 8995    0
# 8996    1
# 8997    0
# 8998    1
# 8999    1
# Name: PurchaseIntent, Length: 9000, dtype: int64

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,random_state=42,test_size=0.2)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
svm_model=SVC(kernel="linear",random_state=42)
svm_model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred=svm_model.predict(x_test)

# %%
accuracy=accuracy_score(y_pred,y_test)
accuracy
# Out:
# 0.8477777777777777

# %%
report=classification_report(y_test,y_pred)
print(f'classification Report:\n{report}')
# Out:
# classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       793
#            1       0.86      0.88      0.87      1007
#
#     accuracy                           0.85      1800
#    macro avg       0.85      0.84      0.85      1800
# weighted avg       0.85      0.85      0.85      1800

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
print(f'confusion matrix:\n{conf_matrix}')
# Out:
# confusion matrix:
# [[644 149]
#  [125 882]]

# %%
new_data = np.array([[18,0,2,1]])  # New input
new_data_scaled = scaler.transform(new_data)  # Apply scaling

prediction = svm_model.predict(new_data_scaled)
prediction
# Out:
# C:\Users\banuz\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
